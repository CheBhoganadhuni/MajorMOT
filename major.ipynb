# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 🔧 Install Python 3.11 and switch alternatives
# !sudo apt-get update -y
# !sudo apt-get install python3.11 python3.11-dev python3.11-distutils -y

# 🔄 Point /usr/bin/python3 to Python 3.11
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.12 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 2
# !sudo update-alternatives --config python3

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py

# %%
# !python --version

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install -r /content/MajorMOT/requirements.txt

# %%
# !python /content/MajorMOT/trackv9.py \
--source /content/MajorMOT/walking1.mp4 \
--yolo-weights /content/MajorMOT/yolov9-c-converted.pt \
--strong-sort-weights /content/MajorMOT/osnet_x1_0_market1501.pt \
--config-strongsort /content/MajorMOT/strong_sort/configs/strong_sort.yaml \
--img 1280 \
--device 0

# %%
from google.colab import files
files.download('/content/MajorMOT/runs/track/exp/walking1.mp4')
